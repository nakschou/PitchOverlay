# %%
import cv2 as cv
from tracker import *
from matplotlib import pyplot as plt

# %%
tracker = EuclideanDistTracker()

cap = cv.VideoCapture(0)
object_detector = cv.createBackgroundSubtractorMOG2(history=100, varThreshold=50)
while cap.isOpened():
    ret, frame = cap.read()
    height, width, _ = frame.shape
    print(height, width)

    #create region of interest
    #roi = frame[100:400, 150:490]

    mask = object_detector.apply(frame)
    _, mask = cv.threshold(mask, 0, 255, cv.THRESH_BINARY)
    contours, _ = cv.findContours(mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
    detections = []
    for cnt in contours:
        #calculate area and remove small elements
        area = cv.contourArea(cnt)
        #draw green contours on the frame where white parts in mask are
        if area > 1000:
            cv.drawContours(frame, [cnt], -1, (0, 255, 0), 2)
            x,y,w,h = cv.boundingRect(cnt)
            cv.rectangle(frame, (x,y), (x+w, y+h), (0, 255, 0), 2)
            detections.append([x,y,w,h])
    
    boxes_ids = tracker.update(detections)
    for box_id in boxes_ids:
        x,y,w,h,id = box_id
        cv.putText(frame, str(id), (x,y-15), cv.FONT_HERSHEY_PLAIN, 2, (0,255,0), 2)
        cv.rectangle(frame, (x,y), (x+w, y+h), (0, 255, 0), 2)
        
    #cv.imshow('roi', roi)
    cv.imshow('Webcam', frame)
    cv.imshow('Mask', mask)

    if cv.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv.destroyAllWindows()
# Out:
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {13: (440, 381), 14: (423, 223)}
# {13: (440, 381), 14: (424, 223)}
# 480 640
# {13: (440, 382), 14: (424, 223), 15: (436, 166)}
# {13: (440, 382), 14: (427, 223), 15: (436, 166)}
# {13: (440, 382), 14: (427, 223), 15: (436, 168)}
# 480 640
# {13: (439, 382), 14: (427, 223), 15: (436, 168)}
# {13: (439, 382), 14: (427, 223), 15: (438, 169), 16: (409, 205)}
# 480 640
# {13: (439, 384), 16: (409, 205), 15: (438, 169)}
# {13: (439, 384), 16: (413, 207), 15: (438, 169)}
# {13: (439, 384), 16: (413, 207), 15: (439, 173)}
# 480 640
# {13: (439, 384), 16: (413, 208), 15: (439, 173), 17: (253, 265)}
# {13: (439, 384), 16: (413, 208), 15: (441, 175), 17: (253, 265)}
# 480 640
# {17: (253, 265), 16: (413, 208), 15: (441, 176)}
# 480 640
# {15: (443, 181), 18: (271, 220)}
# {15: (443, 181), 18: (272, 243)}
# 480 640
# {15: (446, 181), 18: (272, 243)}
# {15: (446, 181), 18: (273, 243)}
# 480 640
# {15: (449, 182), 18: (273, 243)}
# {15: (449, 182), 18: (277, 243)}
# 480 640
# {15: (453, 192), 18: (277, 243)}
# {15: (453, 192), 18: (279, 243)}
# 480 640
# {15: (452, 206), 18: (279, 243)}
# {15: (452, 206), 18: (281, 243)}
# 480 640
# {15: (454, 206), 18: (281, 243)}
# {15: (454, 206), 18: (282, 243)}
# 480 640
# {15: (455, 206), 18: (282, 243)}
# {15: (455, 206), 18: (281, 243)}
# 480 640
# {15: (456, 222), 18: (281, 243)}
# {15: (456, 222), 18: (281, 242)}
# 480 640
# {15: (440, 216), 18: (281, 242)}
# {15: (440, 216), 18: (282, 242)}
# 480 640
# {15: (440, 216), 18: (284, 242), 19: (466, 222)}
# 480 640
# {19: (467, 211), 18: (284, 242)}
# {19: (467, 211), 18: (285, 229)}
# 480 640
# {19: (466, 222), 18: (285, 229)}
# {19: (466, 222), 18: (286, 228)}
# 480 640
# {19: (465, 209), 18: (286, 228)}
# {19: (465, 209), 18: (285, 214)}
# 480 640
# {19: (464, 208), 18: (285, 214)}
# 480 640
# {19: (463, 212), 20: (292, 190)}
# 480 640
# {19: (462, 203)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {21: (282, 217)}
# 480 640
# {21: (279, 216)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {22: (222, 454)}
# 480 640
# 480 640
# 480 640
# {24: (256, 420), 25: (124, 429), 26: (155, 400)}
# 480 640
# 480 640
# {27: (153, 462), 28: (126, 420), 29: (255, 382), 30: (284, 464)}
# {27: (153, 462), 28: (124, 420), 29: (255, 382), 30: (284, 464)}
# 480 640
# {30: (284, 464), 27: (153, 462), 28: (124, 421), 31: (292, 385)}
# 480 640
# 480 640
# {33: (70, 446), 34: (205, 422)}
# 480 640
# {34: (198, 423)}
# 480 640
# {34: (195, 424)}
# 480 640
# {34: (194, 424)}
# 480 640
# {34: (193, 424)}
# 480 640
# {34: (192, 425)}
# 480 640
# {34: (192, 427)}
# 480 640
# {34: (193, 428)}
# 480 640
# 480 640
# {35: (272, 435), 36: (136, 430), 37: (108, 458)}
# 480 640
# {37: (119, 458), 35: (272, 435)}
# {37: (119, 458), 35: (248, 439), 38: (147, 436)}
# 480 640
# {37: (119, 458), 38: (155, 436), 35: (248, 439)}
# {37: (119, 458), 38: (155, 436), 35: (248, 439)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {40: (264, 451), 41: (121, 462)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
