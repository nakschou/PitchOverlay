# %%
import cv2 as cv
from tracker import *
from matplotlib import pyplot as plt

# %%
tracker = EuclideanDistTracker()

cap = cv.VideoCapture(0)
object_detector = cv.createBackgroundSubtractorMOG2(history=100, varThreshold=50)
while cap.isOpened():
    ret, frame = cap.read()
    height, width, _ = frame.shape
    print(height, width)

    #create region of interest
    #roi = frame[100:400, 150:490]

    mask = object_detector.apply(frame)
    _, mask = cv.threshold(mask, 0, 255, cv.THRESH_BINARY)
    contours, _ = cv.findContours(mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
    detections = []
    for cnt in contours:
        #calculate area and remove small elements
        area = cv.contourArea(cnt)
        #draw green contours on the frame where white parts in mask are
        if area > 1000:
            cv.drawContours(frame, [cnt], -1, (0, 255, 0), 2)
            x,y,w,h = cv.boundingRect(cnt)
            cv.rectangle(frame, (x,y), (x+w, y+h), (0, 255, 0), 2)
            detections.append([x,y,w,h])
    
    boxes_ids = tracker.update(detections)
    for box_id in boxes_ids:
        x,y,w,h,id = box_id
        cv.putText(frame, str(id), (x,y-15), cv.FONT_HERSHEY_PLAIN, 2, (0,255,0), 2)
        cv.rectangle(frame, (x,y), (x+w, y+h), (0, 255, 0), 2)
        
    #cv.imshow('roi', roi)
    cv.imshow('Webcam', frame)
    cv.imshow('Mask', mask)

    if cv.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv.destroyAllWindows()
# Out:
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {1: (334, 321), 2: (314, 274), 3: (166, 451), 4: (497, 447)}
# 480 640
# {3: (166, 449), 4: (497, 447), 1: (334, 321)}
# {3: (166, 449), 4: (498, 446), 1: (334, 321)}
# {3: (166, 449), 4: (498, 446), 1: (327, 318)}
# 480 640
# {3: (165, 448), 4: (498, 446), 1: (327, 318)}
# {3: (165, 448), 4: (498, 445), 1: (327, 318)}
# {3: (165, 448), 4: (498, 445), 1: (327, 315)}
# 480 640
# {3: (164, 446), 4: (498, 445), 1: (327, 315), 5: (328, 156)}
# {3: (164, 446), 4: (500, 444), 1: (327, 315), 5: (328, 156)}
# {3: (164, 446), 4: (500, 444), 1: (327, 313), 5: (328, 156)}
# {3: (164, 446), 4: (500, 444), 1: (327, 313), 5: (326, 149)}
# 480 640
# {3: (163, 445), 4: (500, 444), 1: (327, 313), 5: (326, 149)}
# {3: (163, 445), 4: (500, 443), 1: (327, 313), 5: (326, 149)}
# {3: (163, 445), 4: (500, 443), 1: (327, 309), 5: (326, 149)}
# {3: (163, 445), 4: (500, 443), 1: (327, 309), 5: (317, 145), 6: (297, 304), 7: (218, 211)}
# 480 640
# {3: (162, 444), 4: (500, 443), 1: (327, 309), 6: (297, 304), 7: (218, 211), 5: (317, 145)}
# {3: (162, 444), 4: (502, 442), 1: (327, 309), 6: (297, 304), 7: (218, 211), 5: (317, 145)}
# {3: (162, 444), 4: (502, 442), 1: (327, 301), 6: (297, 304), 7: (218, 211), 5: (317, 145)}
# 480 640
# {3: (160, 442), 4: (502, 442), 1: (327, 301), 8: (304, 181)}
# {3: (160, 442), 4: (502, 440), 1: (327, 301), 8: (304, 181)}
# {3: (160, 442), 4: (502, 440), 1: (327, 298), 8: (304, 181)}
# {3: (160, 442), 4: (502, 440), 1: (327, 298), 8: (321, 178), 9: (368, 298)}
# 480 640
# {3: (159, 440), 4: (502, 440), 1: (327, 298), 9: (368, 298), 8: (321, 178)}
# {3: (159, 440), 4: (502, 438), 1: (327, 298), 9: (368, 298), 8: (321, 178)}
# {3: (159, 440), 4: (502, 438), 1: (325, 296), 9: (368, 298), 8: (321, 178)}
# {3: (159, 440), 4: (502, 438), 1: (325, 296), 9: (368, 294), 8: (321, 178)}
# {3: (159, 440), 4: (502, 438), 1: (325, 296), 9: (368, 294), 8: (321, 174)}
# 480 640
# {3: (155, 438), 4: (502, 438), 1: (325, 296), 9: (368, 294), 8: (321, 174)}
# {3: (155, 438), 4: (504, 436), 1: (325, 296), 9: (368, 294), 8: (321, 174)}
# {3: (155, 438), 4: (504, 436), 1: (324, 291), 9: (368, 294), 8: (321, 174)}
# {3: (155, 438), 4: (504, 436), 1: (324, 291), 9: (367, 290), 8: (321, 174)}
# {3: (155, 438), 4: (504, 436), 1: (303, 286), 9: (367, 290), 8: (321, 174)}
# {3: (155, 438), 4: (504, 436), 1: (303, 286), 9: (367, 290), 8: (320, 169)}
# 480 640
# {3: (155, 438), 4: (504, 436), 1: (303, 286), 9: (367, 290), 8: (320, 169)}
# {3: (155, 438), 4: (504, 436), 1: (303, 286), 9: (367, 290), 8: (320, 169)}
# {3: (155, 438), 4: (504, 436), 1: (324, 291), 9: (367, 290), 8: (320, 169)}
# {3: (155, 438), 4: (504, 436), 1: (334, 286), 9: (367, 290), 8: (320, 169)}
# {3: (155, 438), 4: (504, 436), 1: (334, 286), 9: (367, 290), 8: (320, 169)}
# 480 640
# {3: (153, 437), 4: (504, 436), 1: (334, 286), 8: (320, 169)}
# {3: (153, 437), 4: (505, 435), 1: (334, 286), 8: (320, 169)}
# {3: (153, 437), 4: (505, 435), 1: (323, 287), 8: (320, 169)}
# {3: (153, 437), 4: (505, 435), 1: (326, 267), 8: (320, 169)}
# {3: (153, 437), 4: (505, 435), 1: (326, 267), 8: (319, 167)}
# 480 640
# {3: (151, 436), 4: (505, 435), 1: (326, 267), 8: (319, 167)}
# {3: (151, 436), 4: (508, 434), 1: (326, 267), 8: (319, 167)}
# {3: (151, 436), 4: (508, 434), 1: (322, 286), 8: (319, 167)}
# {3: (151, 436), 4: (508, 434), 1: (325, 264), 8: (319, 167)}
# {3: (151, 436), 4: (508, 434), 1: (325, 264), 8: (318, 161)}
# 480 640
# {3: (147, 433), 4: (508, 434), 1: (325, 264), 8: (318, 161)}
# {3: (147, 433), 4: (509, 431), 1: (325, 264), 8: (318, 161)}
# {3: (147, 433), 4: (509, 431), 1: (321, 281), 8: (318, 161)}
# {3: (147, 433), 4: (509, 431), 1: (321, 281), 8: (316, 150), 10: (330, 256)}
# 480 640
# {3: (145, 432), 4: (509, 431), 1: (321, 281), 10: (330, 256), 8: (316, 150)}
# {3: (145, 432), 4: (510, 431), 1: (321, 281), 10: (330, 256), 8: (316, 150)}
# {3: (145, 432), 4: (510, 431), 1: (321, 280), 10: (330, 256), 8: (316, 150)}
# {3: (145, 432), 4: (510, 431), 1: (321, 280), 10: (348, 253), 8: (316, 150)}
# {3: (145, 432), 4: (510, 431), 1: (321, 280), 10: (348, 253), 8: (316, 145)}
# 480 640
# {3: (144, 431), 4: (510, 431), 1: (321, 280), 10: (348, 253), 8: (316, 145)}
# {3: (144, 431), 4: (511, 430), 1: (321, 280), 10: (348, 253), 8: (316, 145)}
# 480 640
# {3: (142, 430), 4: (511, 430), 11: (315, 216)}
# {3: (142, 430), 4: (513, 429), 11: (315, 216)}
# {3: (142, 430), 4: (513, 429), 11: (325, 215)}
# {3: (142, 430), 4: (513, 429), 11: (315, 209)}
# 480 640
# {3: (141, 429), 4: (513, 429), 11: (315, 209)}
# {3: (141, 429), 4: (513, 428), 11: (315, 209)}
# {3: (141, 429), 4: (513, 428), 11: (325, 207), 12: (319, 292)}
# 480 640
# {3: (141, 429), 4: (513, 428), 12: (319, 292), 11: (325, 207), 13: (315, 131)}
# {3: (141, 429), 4: (514, 427), 12: (319, 292), 11: (325, 207), 13: (315, 131)}
# {3: (141, 429), 4: (514, 427), 12: (319, 292), 11: (321, 198), 13: (315, 131)}
# {3: (141, 429), 4: (514, 427), 12: (319, 292), 11: (316, 202), 13: (315, 131)}
# 480 640
# {3: (141, 428), 4: (514, 427), 11: (316, 202)}
# {3: (141, 428), 4: (514, 426), 11: (316, 202)}
# {3: (141, 428), 4: (514, 426), 11: (321, 194), 14: (318, 276)}
# 480 640
# {3: (141, 428), 4: (514, 426), 14: (318, 276), 11: (321, 194), 15: (315, 124)}
# {3: (141, 428), 4: (515, 425), 14: (318, 276), 11: (321, 194), 15: (315, 124)}
# {3: (141, 428), 4: (515, 425), 14: (318, 274), 11: (321, 194), 15: (315, 124)}
# {3: (141, 428), 4: (515, 425), 14: (318, 274), 11: (321, 189), 15: (315, 124)}
# {3: (141, 428), 4: (515, 425), 14: (318, 274), 11: (321, 189), 15: (315, 117)}
# 480 640
# {3: (140, 427), 4: (515, 425), 14: (318, 274), 11: (321, 189), 15: (315, 117)}
# {3: (140, 427), 4: (515, 424), 14: (318, 274), 11: (321, 189), 15: (315, 117)}
# {3: (140, 427), 4: (515, 424), 14: (318, 271), 11: (321, 189), 15: (315, 117)}
# {3: (140, 427), 4: (515, 424), 14: (318, 271), 11: (322, 186), 15: (315, 117)}
# {3: (140, 427), 4: (515, 424), 14: (318, 271), 11: (322, 186), 15: (315, 114)}
# 480 640
# {3: (140, 426), 4: (515, 424), 14: (318, 271), 11: (322, 186), 15: (315, 114)}
# {3: (140, 426), 4: (515, 423), 14: (318, 271), 11: (322, 186), 15: (315, 114)}
# {3: (140, 426), 4: (515, 423), 14: (318, 269), 11: (322, 186), 15: (315, 114)}
# {3: (140, 426), 4: (515, 423), 14: (318, 269), 11: (321, 186), 15: (315, 114)}
# {3: (140, 426), 4: (515, 423), 14: (318, 269), 11: (321, 186), 15: (315, 109)}
# 480 640
# {3: (140, 426), 4: (515, 423), 14: (318, 269), 11: (321, 186), 15: (315, 109)}
# {3: (140, 426), 4: (516, 423), 14: (318, 269), 11: (321, 186), 15: (315, 109)}
# {3: (140, 426), 4: (516, 423), 14: (317, 264), 11: (321, 186), 15: (315, 109)}
# {3: (140, 426), 4: (516, 423), 14: (317, 264), 11: (321, 186), 15: (315, 102)}
# 480 640
# {3: (141, 426), 4: (516, 423), 14: (317, 264), 15: (315, 102)}
# {3: (141, 426), 4: (516, 423), 14: (317, 264), 15: (315, 102)}
# {3: (141, 426), 4: (516, 423), 14: (326, 247), 15: (315, 102)}
# {3: (141, 426), 4: (516, 423), 14: (326, 247), 15: (315, 98)}
# 480 640
# {3: (140, 426), 4: (516, 423), 14: (326, 247), 15: (315, 98)}
# {3: (140, 426), 4: (516, 423), 14: (326, 247), 15: (315, 98)}
# {3: (140, 426), 4: (516, 423), 14: (327, 242), 15: (315, 98)}
# {3: (140, 426), 4: (516, 423), 14: (327, 242), 15: (314, 96)}
# 480 640
# {3: (141, 426), 4: (516, 423), 14: (327, 242), 15: (314, 96)}
# {3: (141, 426), 4: (516, 423), 14: (327, 242), 15: (314, 96)}
# {3: (141, 426), 4: (516, 423), 14: (326, 244), 15: (314, 96)}
# {3: (141, 426), 4: (516, 423), 14: (326, 244), 15: (294, 85)}
# 480 640
# {3: (137, 426), 4: (516, 423), 14: (326, 244), 15: (294, 85)}
# {3: (137, 426), 4: (516, 423), 14: (326, 244), 15: (294, 85)}
# {3: (137, 426), 4: (516, 423), 14: (304, 242), 15: (294, 85), 16: (402, 232)}
# 480 640
# {3: (137, 426), 4: (516, 423), 16: (402, 232), 14: (323, 249), 17: (308, 51)}
# 480 640
# {14: (322, 254), 18: (263, 51)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {19: (318, 243)}
# 480 640
# {19: (318, 243)}
# 480 640
# {19: (321, 236)}
# 480 640
# {19: (321, 236)}
# 480 640
# {19: (331, 233)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {21: (248, 131)}
# 480 640
# {21: (263, 127)}
# 480 640
# 480 640
# {22: (330, 139)}
# 480 640
# {22: (349, 137), 23: (348, 325)}
# 480 640
# {23: (343, 334), 22: (349, 137)}
# {23: (343, 334), 22: (356, 141), 24: (422, 306)}
# 480 640
# {23: (343, 333), 24: (422, 306), 22: (356, 141)}
# {23: (343, 333), 24: (424, 308), 22: (356, 141)}
# {23: (343, 333), 24: (424, 308), 22: (356, 138)}
# 480 640
# {23: (344, 333), 24: (424, 308), 22: (356, 138)}
# {23: (344, 333), 24: (426, 311), 22: (356, 138)}
# 480 640
# {23: (349, 332), 24: (426, 311)}
# {23: (349, 332), 24: (428, 313)}
# 480 640
# {23: (352, 338), 24: (428, 313), 25: (313, 258)}
# {23: (352, 338), 24: (432, 313), 25: (313, 258)}
# {23: (352, 338), 24: (432, 313), 25: (316, 259)}
# 480 640
# {23: (352, 338), 24: (432, 313), 25: (320, 255)}
# 480 640
# {25: (320, 255), 26: (394, 284)}
# 480 640
# {26: (398, 282)}
# 480 640
# {26: (402, 279)}
# 480 640
# 480 640
# 480 640
# {29: (425, 277)}
# 480 640
# {29: (429, 277)}
# 480 640
# {29: (443, 279)}
# 480 640
# {29: (446, 279)}
# 480 640
# {29: (454, 277)}
# 480 640
# {29: (457, 265)}
# 480 640
# {29: (460, 265)}
# 480 640
# {29: (459, 265)}
# 480 640
# {29: (462, 264)}
# 480 640
# {29: (460, 245)}
# 480 640
# {29: (460, 245), 30: (493, 277)}
# 480 640
# {30: (488, 273)}
# 480 640
# 480 640
# 480 640
# 480 640
# {31: (387, 120)}
# 480 640
# {31: (378, 119)}
# 480 640
# {31: (367, 118)}
# 480 640
# {31: (358, 117)}
# 480 640
# {31: (347, 118)}
# 480 640
# {31: (336, 122)}
# 480 640
# 480 640
# {32: (299, 131), 33: (220, 282)}
# 480 640
# {33: (209, 273), 32: (299, 131)}
# 480 640
# {33: (212, 263), 34: (334, 115)}
# 480 640
# {33: (223, 259)}
# 480 640
# 480 640
# {36: (212, 253)}
# 480 640
# {36: (208, 240)}
# 480 640
# {36: (205, 239)}
# 480 640
# {36: (183, 239)}
# 480 640
# {36: (181, 239)}
# 480 640
# {36: (180, 239)}
# 480 640
# {36: (181, 240)}
# 480 640
# {36: (174, 248)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {40: (291, 116)}
# 480 640
# {40: (298, 118)}
# 480 640
# {40: (308, 122)}
# 480 640
# {40: (314, 125)}
# 480 640
# {40: (324, 128)}
# 480 640
# {40: (328, 127)}
# 480 640
# {40: (341, 124)}
# 480 640
# {40: (350, 124), 41: (316, 310)}
# 480 640
# {41: (323, 315), 40: (350, 124)}
# {41: (323, 315), 40: (358, 122), 42: (468, 303)}
# 480 640
# {41: (327, 315), 42: (468, 303), 40: (358, 122)}
# {41: (327, 315), 42: (474, 290), 40: (358, 122)}
# 480 640
# {41: (318, 313), 42: (474, 290)}
# {41: (318, 313), 42: (478, 269)}
# 480 640
# {41: (325, 312), 42: (478, 269)}
# {41: (325, 312), 42: (480, 272)}
# 480 640
# {41: (328, 307), 42: (480, 272)}
# {41: (328, 307), 42: (484, 281)}
# 480 640
# {41: (328, 298), 42: (484, 281)}
# {41: (328, 298), 42: (488, 285)}
# 480 640
# {41: (332, 298), 42: (488, 285), 43: (407, 134)}
# {41: (332, 298), 42: (484, 290), 43: (407, 134)}
# {41: (332, 298), 42: (484, 290), 43: (413, 134)}
# 480 640
# {41: (337, 298), 42: (484, 290), 43: (413, 134)}
# {41: (337, 298), 42: (492, 291), 43: (413, 134)}
# {41: (337, 298), 42: (492, 291), 43: (419, 135)}
# 480 640
# {41: (340, 298), 42: (492, 291), 43: (419, 135)}
# {41: (340, 298), 42: (493, 290), 43: (419, 135)}
# {41: (340, 298), 42: (493, 290), 43: (424, 138)}
# 480 640
# {41: (340, 297), 42: (493, 290), 43: (424, 138)}
# 480 640
# {41: (346, 295), 44: (445, 265)}
# {41: (346, 295), 44: (449, 264)}
# 480 640
# {41: (346, 295), 44: (452, 264)}
# 480 640
# {44: (454, 264)}
# 480 640
# {44: (456, 264)}
# 480 640
# 480 640
# {45: (504, 292), 46: (441, 146)}
# {45: (504, 292), 46: (441, 145)}
# 480 640
# {45: (504, 292), 46: (442, 143), 47: (484, 367), 48: (541, 251)}
# 480 640
# {47: (485, 365), 48: (541, 251), 46: (442, 143)}
# {47: (485, 365), 48: (542, 251), 46: (442, 143)}
# {47: (485, 365), 48: (542, 251), 46: (458, 137)}
# 480 640
# {47: (485, 365), 48: (543, 249), 46: (458, 137)}
# 480 640
# {48: (545, 249)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {49: (480, 322)}
# 480 640
# {49: (457, 322)}
# 480 640
# {49: (457, 321)}
# 480 640
# {49: (457, 318)}
# 480 640
# {49: (454, 316)}
# 480 640
# {49: (451, 314)}
# 480 640
# {49: (451, 310)}
# 480 640
# {49: (449, 309)}
# 480 640
# {49: (447, 306)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {50: (425, 307)}
# 480 640
# {50: (426, 301)}
# 480 640
# {50: (424, 295)}
# 480 640
# {50: (419, 293)}
# 480 640
# {50: (420, 282)}
# 480 640
# {50: (411, 277)}
# 480 640
# {50: (411, 276), 51: (398, 204)}
# {50: (411, 276), 51: (398, 203)}
# 480 640
# {50: (410, 276), 51: (398, 203)}
# {50: (410, 276), 51: (392, 202)}
# 480 640
# {50: (407, 279), 51: (392, 202)}
# {50: (407, 279), 51: (392, 201)}
# 480 640
# {50: (405, 278), 51: (392, 201)}
# {50: (405, 278), 51: (392, 202)}
# 480 640
# {50: (405, 273), 51: (392, 202)}
# {50: (405, 273), 51: (388, 198)}
# 480 640
# {50: (409, 270), 51: (388, 198)}
# {50: (409, 270), 51: (385, 198)}
# 480 640
# {50: (409, 266), 51: (385, 198)}
# {50: (409, 266), 51: (382, 196)}
# 480 640
# {50: (403, 266), 51: (382, 196)}
# 480 640
# {50: (403, 265)}
# 480 640
# {50: (402, 265)}
# 480 640
# {50: (404, 255)}
# 480 640
# {50: (400, 254)}
# 480 640
# {50: (399, 254)}
# 480 640
# {50: (398, 245)}
# 480 640
# {50: (398, 244)}
# 480 640
# {50: (397, 241)}
# 480 640
# {50: (384, 240)}
# 480 640
# {50: (384, 240)}
# 480 640
# {50: (384, 239)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
