# %%
import cv2 as cv
from tracker import *
from matplotlib import pyplot as plt

# %%
tracker = EuclideanDistTracker()

cap = cv.VideoCapture(0)
object_detector = cv.createBackgroundSubtractorMOG2(history=100, varThreshold=50)
while cap.isOpened():
    ret, frame = cap.read()
    height, width, _ = frame.shape
    print(height, width)

    #create region of interest
    #roi = frame[100:400, 150:490]

    mask = object_detector.apply(frame)
    _, mask = cv.threshold(mask, 200, 255, cv.THRESH_BINARY)
    contours, _ = cv.findContours(mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
    detections = []
    for cnt in contours:
        #calculate area and remove small elements
        area = cv.contourArea(cnt)
        #draw green contours on the frame where white parts in mask are
        if area > 3000:
            cv.drawContours(frame, [cnt], -1, (0, 255, 0), 2)
            x,y,w,h = cv.boundingRect(cnt)
            cv.rectangle(frame, (x,y), (x+w, y+h), (0, 255, 0), 2)
            detections.append([x,y,w,h])
    
    boxes_ids = tracker.update(detections)
    for box_id in boxes_ids:
        x,y,w,h,id = box_id
        cv.putText(frame, str(id), (x,y-15), cv.FONT_HERSHEY_PLAIN, 2, (0,255,0), 2)
        cv.rectangle(frame, (x,y), (x+w, y+h), (0, 255, 0), 2)
        
    #cv.imshow('roi', roi)
    cv.imshow('Webcam', frame)
    cv.imshow('Mask', mask)

    if cv.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv.destroyAllWindows()
# Out:
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {8: (327, 306), 9: (576, 318), 10: (320, 240)}
# 480 640
# {10: (320, 230), 11: (450, 239), 12: (257, 244), 13: (260, 25), 14: (331, 327)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {18: (183, 331)}
# 480 640
# {18: (165, 316)}
# 480 640
# {18: (162, 306)}
# 480 640
# {18: (160, 299)}
# 480 640
# {18: (145, 296), 19: (269, 230)}
# 480 640
# {19: (269, 230), 18: (159, 295)}
# 480 640
# {18: (159, 296)}
# 480 640
# 480 640
# {20: (190, 301)}
# 480 640
# {20: (194, 306)}
# 480 640
# 480 640
# {21: (181, 409), 22: (120, 233), 23: (207, 260)}
# 480 640
# {21: (182, 426), 24: (182, 222)}
# {21: (182, 426), 24: (164, 213)}
# 480 640
# {21: (182, 426), 24: (164, 213)}
# {21: (182, 426), 24: (179, 211)}
# 480 640
# 480 640
# {25: (141, 215)}
# 480 640
# {25: (147, 216)}
# 480 640
# {25: (131, 216)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {26: (120, 205)}
# 480 640
# {26: (140, 205)}
# 480 640
# {26: (157, 201)}
# 480 640
# 480 640
# 480 640
# {28: (209, 426), 29: (136, 195), 30: (250, 184)}
# {28: (209, 426), 29: (151, 192), 30: (250, 184)}
# {28: (209, 426), 29: (151, 192), 30: (262, 183)}
# 480 640
# {28: (214, 426), 29: (151, 192), 30: (262, 183)}
# 480 640
# {28: (218, 426), 31: (236, 186)}
# 480 640
# {28: (221, 429), 32: (300, 172), 33: (200, 156)}
# {28: (221, 429), 32: (310, 167), 33: (200, 156)}
# {28: (221, 429), 32: (310, 167), 33: (217, 153)}
# 480 640
# {28: (228, 430), 32: (310, 167), 33: (217, 153)}
# {28: (228, 430), 32: (312, 163), 33: (217, 153), 34: (381, 204)}
# {28: (228, 430), 32: (312, 163), 33: (227, 137), 34: (381, 204)}
# 480 640
# {28: (229, 430), 34: (381, 204), 32: (312, 163), 33: (227, 137)}
# {28: (229, 430), 34: (388, 202), 32: (312, 163), 33: (227, 137)}
# {28: (229, 430), 34: (388, 202), 32: (332, 160), 33: (227, 137)}
# {28: (229, 430), 34: (388, 202), 32: (332, 160), 33: (237, 132)}
# 480 640
# {28: (232, 430), 34: (388, 202), 32: (332, 160), 33: (237, 132)}
# {28: (232, 430), 34: (395, 214), 32: (332, 160), 33: (237, 132)}
# {28: (232, 430), 34: (395, 214), 32: (336, 155), 33: (237, 132)}
# {28: (232, 430), 34: (395, 214), 32: (336, 155), 33: (244, 131)}
# 480 640
# {28: (241, 433), 34: (395, 214), 32: (336, 155), 33: (244, 131)}
# {28: (241, 433), 34: (398, 213), 32: (336, 155), 33: (244, 131)}
# {28: (241, 433), 34: (398, 213), 32: (331, 157), 33: (244, 131)}
# 480 640
# {28: (243, 433), 34: (398, 213), 32: (331, 157), 35: (233, 165)}
# {28: (243, 433), 34: (402, 212), 32: (331, 157), 35: (233, 165)}
# {28: (243, 433), 34: (402, 212), 32: (336, 154), 35: (233, 165)}
# 480 640
# {28: (243, 433), 34: (404, 210), 32: (336, 154), 36: (256, 128)}
# {28: (243, 433), 34: (404, 210), 32: (340, 151), 36: (256, 128)}
# 480 640
# {34: (404, 208), 32: (340, 151), 37: (234, 169)}
# {34: (404, 208), 32: (343, 147), 37: (234, 169)}
# {34: (404, 208), 32: (343, 147), 37: (236, 165)}
# 480 640
# {34: (406, 205), 32: (343, 147), 37: (236, 165)}
# {34: (406, 205), 32: (343, 147), 37: (237, 163)}
# {34: (406, 205), 32: (345, 143), 37: (237, 163)}
# 480 640
# {34: (406, 203), 37: (237, 163), 32: (345, 143)}
# {34: (406, 203), 37: (239, 161), 32: (345, 143)}
# {34: (406, 203), 37: (239, 161), 32: (346, 139)}
# 480 640
# {34: (408, 190), 37: (239, 161), 32: (346, 139)}
# 480 640
# {34: (416, 189), 38: (390, 141)}
# {34: (416, 189), 38: (393, 134)}
# 480 640
# {34: (424, 189), 38: (393, 134), 39: (347, 99)}
# {34: (424, 189), 38: (375, 130), 39: (347, 99)}
# 480 640
# 480 640
# 480 640
# {41: (436, 335), 42: (442, 192), 43: (371, 136)}
# {41: (436, 335), 42: (447, 197), 43: (371, 136)}
# 480 640
# {41: (439, 340), 42: (447, 197), 44: (396, 139), 45: (297, 132)}
# {41: (439, 340), 42: (437, 208), 44: (396, 139), 45: (297, 132)}
# {41: (439, 340), 42: (437, 208), 44: (403, 142), 45: (297, 132)}
# 480 640
# {41: (440, 342), 42: (437, 208), 44: (403, 142)}
# {41: (440, 342), 42: (444, 211), 44: (403, 142)}
# {41: (440, 342), 42: (444, 211), 44: (409, 141)}
# 480 640
# {41: (439, 341), 42: (444, 211), 44: (409, 141)}
# {41: (439, 341), 42: (445, 210), 44: (409, 141)}
# {41: (439, 341), 42: (445, 210), 44: (409, 139)}
# 480 640
# {41: (435, 342), 42: (445, 210), 44: (409, 139)}
# {41: (435, 342), 42: (439, 207), 44: (409, 139)}
# {41: (435, 342), 42: (439, 207), 44: (403, 137)}
# 480 640
# {41: (435, 342), 42: (449, 195), 44: (403, 137)}
# {41: (435, 342), 42: (449, 195), 44: (408, 129)}
# 480 640
# {42: (449, 195), 44: (416, 132), 46: (294, 134)}
# 480 640
# {44: (416, 132), 47: (361, 113)}
# 480 640
# 480 640
# 480 640
# {50: (158, 166)}
# 480 640
# {50: (141, 167), 51: (295, 115), 52: (246, 130)}
# 480 640
# 480 640
# {53: (189, 169), 54: (124, 154)}
# 480 640
# {54: (119, 159), 53: (189, 169)}
# {54: (119, 159), 53: (203, 156)}
# 480 640
# {54: (117, 168), 53: (203, 156)}
# 480 640
# 480 640
# {55: (291, 444), 56: (123, 198)}
# 480 640
# {55: (304, 432)}
# 480 640
# {55: (301, 447)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {61: (294, 439)}
# 480 640
# {61: (294, 439)}
# 480 640
# {61: (297, 433)}
# 480 640
# {61: (303, 425)}
# 480 640
# {61: (319, 417)}
# 480 640
# {61: (324, 417)}
# 480 640
# {61: (344, 416)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {66: (245, 201)}
# 480 640
# 480 640
# {67: (208, 192)}
# 480 640
# {67: (201, 194)}
# 480 640
# 480 640
# 480 640
# {69: (113, 231), 70: (257, 136)}
# 480 640
# {69: (111, 233)}
# 480 640
# {69: (111, 233)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {71: (311, 131)}
# 480 640
# 480 640
# {72: (156, 130), 73: (317, 104)}
# {72: (156, 130), 73: (301, 114)}
# 480 640
# {72: (156, 130), 73: (298, 95), 74: (117, 196)}
# 480 640
# {74: (117, 196), 73: (290, 97)}
# {74: (109, 195), 73: (290, 97)}
# 480 640
# {73: (283, 96), 74: (109, 195)}
# {73: (283, 96), 74: (101, 199)}
# 480 640
# {73: (283, 96), 74: (95, 188), 75: (336, 74)}
# 480 640
# {75: (326, 74), 74: (95, 188), 76: (246, 85)}
# {75: (326, 74), 74: (95, 188), 76: (236, 80), 77: (119, 138)}
# 480 640
# {75: (317, 72), 77: (119, 138), 76: (236, 80)}
# {75: (317, 72), 77: (119, 138), 76: (229, 80), 78: (87, 170)}
# 480 640
# {75: (312, 71), 78: (87, 170), 76: (229, 80)}
# {75: (312, 71), 78: (74, 174), 76: (229, 80)}
# {75: (312, 71), 78: (74, 174), 76: (224, 80)}
# 480 640
# {75: (312, 71), 78: (74, 174), 76: (220, 85), 79: (96, 110)}
# 480 640
# {79: (96, 110), 76: (214, 101), 80: (67, 181)}
# 480 640
# {80: (65, 186), 76: (214, 101)}
# {80: (65, 186), 76: (211, 109)}
# 480 640
# {80: (65, 186), 76: (211, 113)}
# {80: (64, 190), 76: (211, 113)}
# 480 640
# {76: (211, 113), 80: (63, 196)}
# 480 640
# 480 640
# 480 640
# {83: (58, 196)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {84: (370, 294)}
# 480 640
# {84: (373, 312)}
# 480 640
# {84: (383, 319)}
# 480 640
# {84: (386, 318)}
# 480 640
# {84: (388, 317)}
# 480 640
# {84: (391, 316)}
# 480 640
# {84: (393, 315)}
# 480 640
# {84: (396, 314)}
# 480 640
# {84: (399, 314)}
# 480 640
# {84: (400, 317)}
# 480 640
# {84: (401, 316)}
# 480 640
# {84: (403, 307)}
# 480 640
# {84: (403, 285)}
# 480 640
# {84: (409, 281)}
# 480 640
# {84: (414, 270)}
# 480 640
# {84: (416, 267)}
# 480 640
# {84: (418, 258), 85: (390, 81)}
# {84: (418, 258), 85: (390, 77)}
# 480 640
# {84: (418, 258), 85: (390, 77)}
# {84: (418, 258), 85: (390, 76)}
# 480 640
# {84: (422, 252), 85: (390, 76), 86: (582, 416)}
# {84: (422, 252), 85: (387, 72), 86: (582, 416)}
# 480 640
# {86: (582, 414), 84: (422, 252), 85: (387, 72)}
# {86: (582, 414), 84: (422, 252), 85: (388, 67), 87: (411, 197)}
# 480 640
# {86: (582, 411), 87: (411, 197), 85: (388, 67)}
# {86: (582, 411), 87: (420, 206), 85: (388, 67)}
# {86: (582, 411), 87: (420, 206), 85: (398, 61)}
# 480 640
# {86: (582, 411), 87: (420, 206), 85: (398, 61)}
# {86: (582, 411), 87: (411, 190), 85: (398, 61)}
# {86: (582, 411), 87: (411, 190), 85: (398, 61)}
# 480 640
# {86: (582, 410), 87: (411, 190), 85: (398, 61)}
# {86: (582, 410), 87: (410, 190), 85: (398, 61)}
# {86: (582, 410), 87: (410, 190), 85: (402, 58)}
# 480 640
# {86: (582, 408), 87: (410, 190), 85: (402, 58)}
# {86: (582, 408), 87: (409, 184), 85: (402, 58)}
# {86: (582, 408), 87: (409, 184), 85: (412, 55)}
# 480 640
# {86: (582, 407), 87: (409, 184), 85: (412, 55)}
# {86: (582, 407), 87: (408, 173), 85: (412, 55)}
# {86: (582, 407), 87: (408, 173), 85: (399, 47)}
# 480 640
# {86: (582, 406), 87: (408, 173), 85: (399, 47)}
# {86: (582, 406), 87: (409, 172), 85: (399, 47)}
# {86: (582, 406), 87: (409, 172), 85: (401, 44)}
# 480 640
# {86: (582, 404), 87: (409, 172), 85: (401, 44)}
# {86: (582, 404), 87: (410, 193), 85: (401, 44)}
# 480 640
# {86: (582, 403), 87: (410, 193), 88: (366, 56)}
# {86: (582, 403), 87: (410, 189), 88: (366, 56)}
# {86: (582, 403), 87: (410, 189), 88: (362, 56)}
# 480 640
# {86: (582, 402), 87: (410, 189), 88: (362, 56)}
# {86: (582, 402), 87: (411, 187), 88: (362, 56)}
# {86: (582, 402), 87: (411, 187), 88: (360, 56)}
# 480 640
# {86: (582, 401), 87: (411, 187), 88: (360, 56)}
# {86: (582, 401), 87: (411, 187), 88: (362, 56)}
# 480 640
# {86: (581, 395), 88: (362, 56)}
# {86: (581, 395), 88: (358, 56), 89: (420, 180)}
# 480 640
# {86: (582, 389), 89: (420, 180), 88: (358, 56)}
# {86: (582, 389), 89: (420, 180), 88: (355, 56)}
# 480 640
# {86: (582, 389), 88: (356, 56)}
# 480 640
# {88: (350, 56)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# {91: (571, 373)}
# 480 640
# {91: (577, 377)}
# 480 640
# {91: (578, 377)}
# 480 640
# {91: (581, 377)}
# 480 640
# {91: (586, 377)}
# 480 640
# {91: (589, 377)}
# 480 640
# {91: (599, 377)}
# 480 640
# {91: (604, 377)}
# 480 640
# {91: (609, 377)}
# 480 640
# {91: (608, 377)}
# 480 640
# {91: (612, 376)}
# 480 640
# {91: (612, 376)}
# 480 640
# {91: (615, 375)}
# 480 640
# {91: (618, 374)}
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
# 480 640
